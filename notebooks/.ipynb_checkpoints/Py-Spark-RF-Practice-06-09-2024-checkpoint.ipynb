# %% [markdown]
# # Spark with Python
#
# 05-08-2023
# by Thomas Johnson III
#
# This notebook is to practice the usage of Pyspark for personal coding development. A lot of what is seen here will be extensions of existing work or methods for the loaded Python libraries that already exist.

# %%
# Loading in necessary modules and functions.
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
from pyspark.context import SparkContext
from pyspark.mllib.stat import Statistics
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression, GBTRegressor, RandomForestRegressor
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder, TrainValidationSplit
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml import Pipeline
from pyspark.ml.feature import PCA
import time

# %%
# Generate some regression data to be used for fitting and evaluation.
def gen_data():
    np.random.seed(12) # Set a random seed
    # Obtain the simulated data for regression.
    dat_x, dat_y = make_regression(n_samples = 5000, # 5000 cases
                                                   n_features = 25, # 25 variables, by default 10 are infromative.
                                                   noise = 1)
    x_names = []
    for i in range(25):
        x_names.append("X" + str(i+1)) #Get names of X columns
    # Dataframe conversion occurring
    dat_x = pd.DataFrame(dat_x, columns = x_names) 
    dat_y = pd.DataFrame(dat_y, columns = ["y"])
    return(dat_x, dat_y) # Return X and y

# %% [markdown]
# Now we obtain the $\boldsymbol{X}$ and $\boldsymbol{y}$ data.

# %%
X_dat, y_dat = gen_data()

# %% [markdown]
# Combine $\boldsymbol{X}$ and \boldsymbol{y} into one dataframe. Starting in pandas then moving the dataframe into pyspark.

# %%
pop_data = pd.concat([X_dat,y_dat], axis = 1)

# %% [markdown]
# Now that we have the population data, we can start loading into Pyspark.

# %%
# Set up the Spark settings with 4Gb of memory. Set up a spark session to work in.
# SparkContext.setSystemProperty("spark.executor.memory", "4g").setSystemProperty("spark.cores.max", "6")
sp_context = SparkSession.builder.master("local[1]").config("spark.executor.memory", "8g").config("spark.cores.max", "6") \
    .appName("ml_spark").getOrCreate()
# Out:
# 24/06/09 20:11:51 WARN Utils: Your hostname, LAPTOP-9T87KVBO resolves to a loopback address: 127.0.1.1; using 192.168.56.1 instead (on interface eth1)
# 24/06/09 20:11:51 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/06/09 20:11:52 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Move pandas dataframe to Spark in memory
pop_data_sp = sp_context.createDataFrame(pop_data)

# %%
# Calculate some brief summary statistics.
pop_data_sp.select(pop_data_sp.columns[1:5]).summary().show()
# Out:
# 24/06/09 20:11:56 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/06/09 20:11:57 WARN TaskSetManager: Stage 0 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# +-------+--------------------+--------------------+--------------------+--------------------+
# |summary|                  X2|                  X3|                  X4|                  X5|
# +-------+--------------------+--------------------+--------------------+--------------------+
# |  count|                5000|                5000|                5000|                5000|
# |   mean|-0.01210631494364...|-8.85369555971085...|-0.00268963742477...|-0.02023292955390...|
# | stddev|  0.9957392741360688|   1.006254205754425|  1.0083556524718054|  1.0015132191307523|
# |    min| -3.4157248243589216|  -3.654432921988915| -3.5675804306862626| -3.8897380263174064|
# |    25%|  -0.676277675641535| -0.6825850313187773| -0.6808199601427417| -0.6880649901638419|
# |    50%|-0.01392845608911...|4.529808944312057E-4|-0.01630454755484...|-0.01341902585471932|
# |    75%|  0.6391356777594667|  0.6768263942589848|  0.6704488113096037|  0.6501401096039792|
# |    max|   3.407902648447736|  3.8102699875673443|   3.570832933157062|    3.54798776514766|
# +-------+--------------------+--------------------+--------------------+--------------------+

# %%
#Calclate some brief summary statistics
pop_data_sp.select(pop_data_sp.columns[23:]).summary().show()
# Out:
# 24/06/09 20:12:00 WARN TaskSetManager: Stage 3 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# +-------+--------------------+--------------------+-------------------+
# |summary|                 X24|                 X25|                  y|
# +-------+--------------------+--------------------+-------------------+
# |  count|                5000|                5000|               5000|
# |   mean|-0.00498021898128...|-0.02020631205235034| -3.798446493633077|
# | stddev|  0.9877367012402092|  1.0201279396655665| 234.20786791921896|
# |    min|  -3.367035150216294| -3.4850827883691182| -884.2724915998847|
# |    25%| -0.6889496650184208| -0.7074029537948439| -156.7858165392303|
# |    50%|-0.01406311451878...|-0.01767028251457...|-1.7103445920178768|
# |    75%|  0.6693079349083157|  0.6525044474585894| 158.57970199205099|
# |    max|   3.499212619752443|  3.8085663482139127|  972.4118959873122|
# +-------+--------------------+--------------------+-------------------+

# %%
pop_data_sp = pop_data_sp.repartition(10)

# %%
# The train test split.
train_dat, test_dat = pop_data_sp.randomSplit(weights = [0.7, 0.3], seed = 424)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # The train test split.
# ----> 2 train_dat, test_dat = pop_data_sp.randomSplit(weights = [0.7, 0.3], seed = 424)
#
# NameError: name 'pop_data_sp' is not defined

# %% [markdown]
# # Random Forest

# %% [markdown]
# Adding a random forest as well for comparison with the GBT and lienar regression predicive models.

# %%
# random forest regressor model
rfRegress = RandomForestRegressor(labelCol = "y", seed = 9)

# %%
# Construct a pipeline
rf_pipeline_1 = Pipeline(stages = [vec_assembler, rfRegress])

# %%
# constructing the parameter grid
rf_reg_params = ParamGridBuilder()\
    .addGrid(rfRegress.maxDepth, [5, 10])\
    .addGrid(rfRegress.maxBins, [16, 32])\
    .addGrid(rfRegress.numTrees, [10, 20, 30]).build()

# %%
# building cross validaiton object
rf_cross_val = CrossValidator(estimator = rf_pipeline_1,
                              estimatorParamMaps = rf_reg_params,
                              evaluator= RegressionEvaluator(labelCol = "y"),
                                    numFolds = 5)

# %% [markdown]
# Get the time it takes to build the random forest regressor.

# %%
start_time_rf = time.time()
rf_model_fitted = rf_cross_val.fit(train_dat)
end_time_rf = time.time() - start_time_rf
# Out:
# 24/06/09 20:17:07 WARN TaskSetManager: Stage 425 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:07 WARN TaskSetManager: Stage 426 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:07 WARN TaskSetManager: Stage 427 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:08 WARN TaskSetManager: Stage 428 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:08 WARN TaskSetManager: Stage 430 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:08 WARN TaskSetManager: Stage 432 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:08 WARN TaskSetManager: Stage 434 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:08 WARN TaskSetManager: Stage 436 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:08 WARN TaskSetManager: Stage 438 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:09 WARN TaskSetManager: Stage 440 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:09 WARN TaskSetManager: Stage 441 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:09 WARN TaskSetManager: Stage 442 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:09 WARN TaskSetManager: Stage 443 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:09 WARN TaskSetManager: Stage 444 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:09 WARN TaskSetManager: Stage 446 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:09 WARN TaskSetManager: Stage 448 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:09 WARN TaskSetManager: Stage 450 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:09 WARN TaskSetManager: Stage 452 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:09 WARN TaskSetManager: Stage 454 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:10 WARN TaskSetManager: Stage 456 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:10 WARN TaskSetManager: Stage 457 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:10 WARN TaskSetManager: Stage 458 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:10 WARN TaskSetManager: Stage 459 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:10 WARN TaskSetManager: Stage 461 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:10 WARN TaskSetManager: Stage 463 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:10 WARN TaskSetManager: Stage 465 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:10 WARN TaskSetManager: Stage 467 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:10 WARN TaskSetManager: Stage 469 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:11 WARN TaskSetManager: Stage 471 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:11 WARN TaskSetManager: Stage 472 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:11 WARN TaskSetManager: Stage 473 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:11 WARN TaskSetManager: Stage 474 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:11 WARN TaskSetManager: Stage 476 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:11 WARN TaskSetManager: Stage 478 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:11 WARN TaskSetManager: Stage 480 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:11 WARN TaskSetManager: Stage 482 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:11 WARN TaskSetManager: Stage 484 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:11 WARN TaskSetManager: Stage 486 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:11 WARN TaskSetManager: Stage 487 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:11 WARN TaskSetManager: Stage 488 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:11 WARN TaskSetManager: Stage 489 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:11 WARN TaskSetManager: Stage 491 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:12 WARN TaskSetManager: Stage 493 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:12 WARN TaskSetManager: Stage 495 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:12 WARN TaskSetManager: Stage 497 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:12 WARN TaskSetManager: Stage 499 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:12 WARN TaskSetManager: Stage 501 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:12 WARN TaskSetManager: Stage 502 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:12 WARN TaskSetManager: Stage 503 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:12 WARN TaskSetManager: Stage 504 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:12 WARN TaskSetManager: Stage 506 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:12 WARN TaskSetManager: Stage 508 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:12 WARN TaskSetManager: Stage 510 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:12 WARN TaskSetManager: Stage 512 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:13 WARN TaskSetManager: Stage 514 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:13 WARN TaskSetManager: Stage 516 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:13 WARN TaskSetManager: Stage 517 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:13 WARN TaskSetManager: Stage 518 contains a task of very large size (1164 KiB). The maximum recommended task size is 1000 KiB.
# 24/06/09 20:17:13 WARN TaskSetManager: Stage